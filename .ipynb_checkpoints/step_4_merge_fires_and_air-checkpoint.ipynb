# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
from datetime import datetime,date,timedelta

# %%
rds_connection_string = "root:12345678@127.0.0.1/fires"
engine = create_engine(f'mysql+pymysql://{rds_connection_string}')

# %%
wildfire_df = pd.read_sql("select * from cleaned_wildfire_data",con=engine)
# Out:
# /anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)

# %%
wildfire_df = wildfire_df[['fire_id','fire_name', 'discovery_date', 'containment_date', 'size', 'class', 'fire_year']]

# %%
wildfire_df.head()
# Out:
#    fire_id fire_name discovery_date containment_date  size class  fire_year
# 0        0  FOUNTAIN     2005-02-02       2005-02-02  0.10     A       2005
# 1        1    PIGEON     2004-05-12       2004-05-12  0.25     A       2004
# 2        2     SLACK     2004-05-31       2004-05-31  0.10     A       2004
# 3        3      DEER     2004-06-28       2004-07-03  0.10     A       2004
# 4        4  STEVENOT     2004-06-28       2004-07-03  0.10     A       2004

# %%
airquality_df = pd.read_sql("select * from aqi_data", con=engine)
airquality_df.head()
# Out:
#         date  overall_aqi      site_name  year
# 0 2001-01-01          153  San Francisco  2001
# 1 2001-01-02          140  San Francisco  2001
# 2 2001-01-03          140  San Francisco  2001
# 3 2001-01-04          107  San Francisco  2001
# 4 2001-01-05          124  San Francisco  2001

# %%
merged_data_df = airquality_df.merge(wildfire_df,left_on='date', right_on="containment_date", how='left')

# %%
merged_data_df.head()
# Out:
#         date  overall_aqi      site_name  year  fire_id   fire_name  \
# 0 2001-01-01          153  San Francisco  2001  26892.0     LUCERNE
# 1 2001-01-01          153  San Francisco  2001  27620.0    DEBRIS 2
# 2 2001-01-01          153  San Francisco  2001  45869.0     LP HILL
# 3 2001-01-01          153  San Francisco  2001  60502.0       PGE 1
# 4 2001-01-01          153  San Francisco  2001  60589.0  PUMP HOUSE
#
#   discovery_date containment_date  size class  fire_year
# 0     2001-01-01       2001-01-01   0.1     A     2001.0
# 1     2001-01-01       2001-01-01   0.1     A     2001.0
# 2     2001-01-01       2001-01-01   0.1     A     2001.0
# 3     2001-01-01       2001-01-01   0.1     A     2001.0
# 4     2001-01-01       2001-01-01   0.1     A     2001.0

# %%
# and write it to the database
merged_data_df.to_sql(name="fire_and_air_data", con=engine, if_exists="replace", index=False)

# %%
# confirm that there are wildfires with no name
wildfire_df[wildfire_df["containment_date"] == "2014-01-01"]
# Out:
#         fire_id      fire_name discovery_date containment_date  size class  \
# 171166   171166          PIUMA     2014-01-01       2014-01-01   0.3     B
# 171798   171798           None     2014-01-01       2014-01-01   0.9     B
# 172306   172306           None     2014-01-01       2014-01-01  60.0     C
# 172307   172307           None     2014-01-01       2014-01-01   0.3     B
# 172308   172308           None     2014-01-01       2014-01-01   1.0     B
# 172309   172309           None     2014-01-01       2014-01-01   1.0     B
# 172573   172573           None     2014-01-01       2014-01-01   0.1     A
# 172683   172683           None     2014-01-01       2014-01-01   0.1     A
# 173659   173659           None     2014-01-01       2014-01-01   3.5     B
# 173660   173660           None     2014-01-01       2014-01-01   0.3     B
# 173661   173661           None     2014-01-01       2014-01-01   1.8     B
# 185921   185921  REDTAIL/TAC 3     2014-01-01       2014-01-01   1.0     B
#
#         fire_year
# 171166       2014
# 171798       2014
# 172306       2014
# 172307       2014
# 172308       2014
# 172309       2014
# 172573       2014
# 172683       2014
# 173659       2014
# 173660       2014
# 173661       2014
# 185921       2014
