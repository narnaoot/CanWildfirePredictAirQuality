# %%
from sqlalchemy import create_engine
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
rds_connection_string = "root:12345678@127.0.0.1/fires"
engine = create_engine(f'mysql+pymysql://{rds_connection_string}')

# %%
data = pd.read_sql("select * from acres_and_air_data", con=engine)
data.head(30)
# Out:
# /anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)
#     index       date  overall_aqi      site_name  year     size
# 0       0 2001-01-01          153  San Francisco  2001      1.5
# 1       1 2001-01-02          140  San Francisco  2001      0.4
# 2       2 2001-01-03          140  San Francisco  2001      0.5
# 3       3 2001-01-04          107  San Francisco  2001      9.8
# 4       4 2001-01-05          124  San Francisco  2001    146.0
# 5       5 2001-01-06          147  San Francisco  2001      5.5
# 6       6 2001-01-07          150  San Francisco  2001  10363.2
# 7       7 2001-01-08           39  San Francisco  2001     11.1
# 8       8 2001-01-09           43  San Francisco  2001      0.1
# 9       9 2001-01-10           33  San Francisco  2001      0.1
# 10     10 2001-01-11           34  San Francisco  2001      0.0
# 11     11 2001-01-12           34  San Francisco  2001      0.0
# 12     12 2001-01-13           25  San Francisco  2001      3.0
# 13     13 2001-01-14           34  San Francisco  2001      0.3
# 14     14 2001-01-15           39  San Francisco  2001      0.9
# 15     15 2001-01-16           39  San Francisco  2001      1.0
# 16     16 2001-01-17           40  San Francisco  2001      0.0
# 17     17 2001-01-18           79  San Francisco  2001      0.0
# 18     18 2001-01-19          111  San Francisco  2001      1.3
# 19     19 2001-01-20          158  San Francisco  2001      0.1
# 20     20 2001-01-21          162  San Francisco  2001      0.0
# 21     21 2001-01-22          111  San Francisco  2001      0.7
# 22     22 2001-01-23           42  San Francisco  2001      0.0
# 23     23 2001-01-24           45  San Francisco  2001      0.0
# 24     24 2001-01-25           42  San Francisco  2001      0.1
# 25     25 2001-01-26           37  San Francisco  2001      0.0
# 26     26 2001-01-27           38  San Francisco  2001      0.2
# 27     27 2001-01-28           52  San Francisco  2001      0.1
# 28     28 2001-01-29           36  San Francisco  2001      0.0
# 29     29 2001-01-30           39  San Francisco  2001      0.1

# %%
data = data[['date', 'overall_aqi', 'size']]
data.columns = ["date", "air_quality", "acres_burned"]
data.head()
# Out:
#         date  air_quality  acres_burned
# 0 2001-01-01          153           1.5
# 1 2001-01-02          140           0.4
# 2 2001-01-03          140           0.5
# 3 2001-01-04          107           9.8
# 4 2001-01-05          124         146.0

# %%
data.sort_values(by=['acres_burned'], inplace=True, ascending=False)

# %%
data.head()
# Out:
#            date  air_quality  acres_burned
# 4309 2012-10-22           37     315579.25
# 2492 2007-10-31           42     288438.30
# 1037 2003-11-04           33     280059.30
# 4676 2013-10-24           56     255862.90
# 2433 2007-09-02           38     242862.84

# %%
temp = pd.read_sql("select * from aqi_data", con=engine)
temp.head()
# Out:
#         date  overall_aqi      site_name  year
# 0 2001-01-01          153  San Francisco  2001
# 1 2001-01-02          140  San Francisco  2001
# 2 2001-01-03          140  San Francisco  2001
# 3 2001-01-04          107  San Francisco  2001
# 4 2001-01-05          124  San Francisco  2001

# %%
temp[temp['date'] == '2012-10-22']
# Out:
#            date  overall_aqi  site_name  year
# 4309 2012-10-22           37  San Pablo  2012

# %%
wildfire = pd.read_sql("select * from wildfire_data", con=engine)

# %%
wildfire.head()
# Out:
#    index  fire_id fire_name discovery_date containment_date  size class  \
# 0      0        0  FOUNTAIN     2005-02-02       2005-02-02  0.10     A
# 1      1        1    PIGEON     2004-05-12       2004-05-12  0.25     A
# 2      2        2     SLACK     2004-05-31       2004-05-31  0.10     A
# 3      3        3      DEER     2004-06-28       2004-07-03  0.10     A
# 4      4        4  STEVENOT     2004-06-28       2004-07-03  0.10     A
#
#    fire_year        lat        long
# 0       2005  40.036944 -121.005833
# 1       2004  38.933056 -120.404444
# 2       2004  38.984167 -120.735556
# 3       2004  38.559167 -119.913333
# 4       2004  38.559167 -119.933056

# %%
wildfire[wildfire['containment_date'] == '2012-10-22']
# Out:
#        index  fire_id fire_name discovery_date containment_date       size  \
# 79650  79650    79650      MILE     2012-10-21       2012-10-22       0.20
# 80132  80132    80132    PICNIC     2012-10-22       2012-10-22       0.25
# 81174  81174    81174      RUSH     2012-08-12       2012-10-22  315578.80
#
#       class  fire_year        lat        long
# 79650     A       2012  38.788611 -120.194167
# 80132     A       2012  34.086667 -116.928611
# 81174     G       2012  40.615300 -120.115300

# %%
# Assign the data to X and y

X = data[["acres_burned"]]
y = data["air_quality"].values.reshape(-1,1)
print(X.shape, y.shape)
# Out:
# (5110, 1) (5110, 1)

# %%
# Use train_test_split to create training and testing data

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create the model using LinearRegression

model = LinearRegression()

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)


print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.0008480444845551105
# Testing Score: 0.001299273456177752
